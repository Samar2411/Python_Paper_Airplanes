# %% [markdown]
# <a href="https://colab.research.google.com/github/Samar2411/Python_Paper_Airplanes/blob/main/Regex_NLP_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
#Loading in text files
from google.colab import files 
uploaded = files.upload()
#files.download('')

# %%
#Loading in pdfs 
import PyPDF2

# %%
pdf = PyPDF2.PdfFileReader(uploaded)

# %% [markdown]
# # Importing the Regex Module

# %%
import re

# %% [markdown]
# # The compile function will allow us to create a regular expression and assign it to the variable pattern.

# %%
pattern = re.compile()

# %% [markdown]
# The search function takes in a string that we want to look for the regular expression and assigns the matches to a variable called results. The most basic regular expression we can use is the exact word we are looking for.

# %%
results = pattern.search('Restaurant')

# %% [markdown]
# **We need to view the results as the actual results and not as an object so we use results.group.

# %%
results.group()

# %% [markdown]
# #Character Ranges
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Quantifiers
#
# These characters allow us to specify how many times we need to have a certain string to consider a match.
#
# ![image.png](data:image/png;base64,...)

# %%
# Quantifiers

# %% [markdown]
# # Character Classes
#
# These characters allow us to match letters, or numbers.
#
# ![image.png](data:image/png;base64,...)

# %%
# Character Classes

# %% [markdown]
# #Location and Pipes
#
# ![image.png](data:image/png;base64,...)

# %%
# Logical Operators

# %%
#Anchors and Boundaries

# %% [markdown]
# # Substitution
#
# We likely have used or seen find all and replace in text editors like Microsoft word. We can do something similar in Regex. We have to use the sub method and take in the word we want to replace the matches with and the string that we want to edit.

# %%
#Substitution
result = pattern.sub('', text )

# %% [markdown]
# #Findall
#
# If we want to find all of the matches, we actually need to use the findall() function.

# %%
#Special Characters 
results = pattern.findall('r\d{3} - \d{3} - \d{4}')

# %% [markdown]
# # Grouping
#
# In the regex module, we can find parts of our matched string by specifying groups within parenthesis. To do this, we will again, use our group function. To name the groups, we use the syntax within the parenthesis ?P=<group name>
#
# We can also use the syntax \g<1> to get groups in the order they appear.

# %%
matches = pattern.group(' ')

# %% [markdown]
# # Grouping and Substititon
#
# We can also use grouping so that we only replace certain parts of the matched string with the text.
